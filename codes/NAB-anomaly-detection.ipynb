# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import savefig

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs
# Out:
# WARNING:tensorflow:From /opt/homebrew/anaconda3/envs/VAE-LSTM/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)
# Out:
# Device mapping: no known devices.
# WARNING:tensorflow:From /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:33: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# This is a deprecated API that should only be used in TF 1 graph mode and legacy TF 2 graph mode available through `tf.compat.v1`. In all other situations -- namely, eager mode and inside `tf.function` -- you can consume dataset elements using `for elem in dataset: ...` or by explicitly creating iterator via `iterator = iter(dataset)` and fetching its elements via `values = next(iterator)`. Furthermore, this API is not available in TF 2. During the transition from TF 1 to TF 2 you can use `tf.compat.v1.data.make_initializable_iterator(dataset)` to create a TF 1 graph mode style iterator for a dataset created through TF 2 APIs. Note that this should be a transient state of your code base as there are in general no guarantees about the interoperability of TF 1 and TF 2 code.
# conv_1: Tensor("encoder/conv2d/LeakyRelu:0", shape=(?, 24, 1, 32), dtype=float32)
# conv_2: Tensor("encoder/conv2d_1/LeakyRelu:0", shape=(?, 12, 1, 64), dtype=float32)
# conv_3: Tensor("encoder/conv2d_2/LeakyRelu:0", shape=(?, 6, 1, 128), dtype=float32)
# conv_4: Tensor("encoder/conv2d_3/LeakyRelu:0", shape=(?, 1, 1, 512), dtype=float32)
# finish encoder:
# Tensor("encoder/MultivariateNormalDiag/sample/chain_of_shift_of_scale_matvec_linear_operator/forward/shift/forward/add:0", shape=(?, 6), dtype=float32)
#
#
# decoded_2 is: Tensor("decoder/Reshape_1:0", shape=(?, 3, 1, 256), dtype=float32)
# decoded_3 is: Tensor("decoder/Reshape_2:0", shape=(?, 6, 1, 128), dtype=float32)
# decoded_4 is: Tensor("decoder/Reshape_3:0", shape=(?, 24, 1, 32), dtype=float32)
# decoded_5 is: Tensor("decoder/Reshape_4:0", shape=(?, 48, 1, 16), dtype=float32)
# decoded_6 is: Tensor("decoder/conv2d_4/BiasAdd:0", shape=(?, 48, 1, 1), dtype=float32)
# finish decoder:
# Tensor("decoder/Reshape_5:0", shape=(?, 48, 1), dtype=float32)
#
#
# sigma2:
# Tensor("sigma2_dataset/Square:0", shape=(), dtype=float32)
#
# The total number of trainable parameters in the encoder model is: 437380
# The total number of trainable parameters in the decoder model is: 646897
# The total number of trainable parameters in the sigma2_dataset model is: 0
# Total number of trainable parameters in the VAE network is: 1084277
# gvs for dataset: [(<tf.Tensor 'gradients/encoder/conv2d/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 1, 32) dtype=float32>, <tf.Variable 'encoder/conv2d/kernel:0' shape=(3, 1, 1, 32) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d/BiasAdd_grad/tuple/control_dependency_1:0' shape=(32,) dtype=float32>, <tf.Variable 'encoder/conv2d/bias:0' shape=(32,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_1/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 32, 64) dtype=float32>, <tf.Variable 'encoder/conv2d_1/kernel:0' shape=(3, 1, 32, 64) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_1/BiasAdd_grad/tuple/control_dependency_1:0' shape=(64,) dtype=float32>, <tf.Variable 'encoder/conv2d_1/bias:0' shape=(64,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_2/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 64, 128) dtype=float32>, <tf.Variable 'encoder/conv2d_2/kernel:0' shape=(3, 1, 64, 128) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_2/BiasAdd_grad/tuple/control_dependency_1:0' shape=(128,) dtype=float32>, <tf.Variable 'encoder/conv2d_2/bias:0' shape=(128,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_3/Conv2D_grad/tuple/control_dependency_1:0' shape=(6, 1, 128, 512) dtype=float32>, <tf.Variable 'encoder/conv2d_3/kernel:0' shape=(6, 1, 128, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_3/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'encoder/conv2d_3/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/dense/MatMul_grad/tuple/control_dependency_1:0' shape=(512, 24) dtype=float32>, <tf.Variable 'encoder/dense/kernel:0' shape=(512, 24) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/dense/BiasAdd_grad/tuple/control_dependency_1:0' shape=(24,) dtype=float32>, <tf.Variable 'encoder/dense/bias:0' shape=(24,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_mean/MatMul_grad/tuple/control_dependency_1:0' shape=(24, 6) dtype=float32>, <tf.Variable 'encoder/code_mean/kernel:0' shape=(24, 6) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_mean/BiasAdd_grad/tuple/control_dependency_1:0' shape=(6,) dtype=float32>, <tf.Variable 'encoder/code_mean/bias:0' shape=(6,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_std_dev/MatMul_grad/tuple/control_dependency_1:0' shape=(24, 6) dtype=float32>, <tf.Variable 'encoder/code_std_dev/kernel:0' shape=(24, 6) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_std_dev/BiasAdd_grad/tuple/control_dependency_1:0' shape=(6,) dtype=float32>, <tf.Variable 'encoder/code_std_dev/bias:0' shape=(6,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/dense/MatMul_grad/tuple/control_dependency_1:0' shape=(6, 512) dtype=float32>, <tf.Variable 'decoder/dense/kernel:0' shape=(6, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/dense/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'decoder/dense/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d/Conv2D_grad/tuple/control_dependency_1:0' shape=(1, 1, 512, 768) dtype=float32>, <tf.Variable 'decoder/conv2d/kernel:0' shape=(1, 1, 512, 768) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d/BiasAdd_grad/tuple/control_dependency_1:0' shape=(768,) dtype=float32>, <tf.Variable 'decoder/conv2d/bias:0' shape=(768,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_1/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 256, 256) dtype=float32>, <tf.Variable 'decoder/conv2d_1/kernel:0' shape=(3, 1, 256, 256) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_1/BiasAdd_grad/tuple/control_dependency_1:0' shape=(256,) dtype=float32>, <tf.Variable 'decoder/conv2d_1/bias:0' shape=(256,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_2/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 128, 128) dtype=float32>, <tf.Variable 'decoder/conv2d_2/kernel:0' shape=(3, 1, 128, 128) ...
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:77: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   conv_1 = tf.layers.conv2d(input_tensor,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:85: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   conv_2 = tf.layers.conv2d(inputs=conv_1,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:93: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   conv_3 = tf.layers.conv2d(inputs=conv_2,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:101: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   conv_4 = tf.layers.conv2d(inputs=conv_3,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:143: UserWarning: `tf.layers.flatten` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Flatten` instead.
#   encoded_signal = tf.layers.flatten(conv_4)
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:144: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   encoded_signal = tf.layers.dense(encoded_signal,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:148: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.code_mean = tf.layers.dense(encoded_signal,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:153: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.code_std_dev = tf.layers.dense(encoded_signal,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:166: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   decoded_1 = tf.layers.dense(encoded,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:222: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   decoded_2 = tf.layers.conv2d(decoded_1,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:229: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   decoded_3 = tf.layers.conv2d(decoded_2,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:240: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   decoded_4 = tf.layers.conv2d(decoded_3,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:251: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   decoded_5 = tf.layers.conv2d(decoded_4,
# /Users/jinjae/Documents/Code/VAE-LSTM-Code-Implementation/codes/models.py:262: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   decoded = tf.layers.conv2d(inputs=decoded_5,
# Reach the definition of loss for VAE
# global_step/global_step: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/global_step/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/global_step/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/cur_epoch: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/cur_epoch/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/cur_epoch/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Equal: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Equal_1: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/LogicalAnd: (LogicalAnd): /job:localhost/replica:0/task:0/device:CPU:0
# seed2: (SelectV2): /job:localhost/replica:0/task:0/device:CPU:0
# ShuffleDataset: (ShuffleDataset): /job:localhost/replica:0/task:0/device:CPU:0
# RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# BatchDatasetV2: (BatchDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# IteratorToStringHandle: (IteratorToStringHandle): /job:localhost/replica:0/task:0/device:CPU:0
# IteratorGetNext: (IteratorGetNext): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/ExpandDims: (ExpandDims): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/concat/values_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Prod_1: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/floordiv: (FloorDiv): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Maximum: (Maximum): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat/values_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/concat/values_0: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/concat/values_0: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/normal/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/normal/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/normal/random_normal: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Shape_2: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/strided_slice_2: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/transpose: (Transpose): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/event_shape_tensor/event_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/NotEqual: (NotEqual): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SelectV2: (SelectV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_2: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/transpose: (Transpose): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_3: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_4: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Reshape_2: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/chain_of_shift_of_scale_matvec_linear_operator/forward/scale_matvec_linear_operator/forward/LinearOperatorDiag/matvec/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/chain_of_shift_of_scale_matvec_linear_operator/forward/shift/forward/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Switch: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/switch_t: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/switch_f: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/pred_id: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Switch_1: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Switch_2: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Merge: (Merge): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/DepthToSpace: (DepthToSpace): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_2: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/DepthToSpace_1: (DepthToSpace): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_3: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/DepthToSpace_2: (DepthToSpace): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_4: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# 2024-01-29 14:48:15.491711: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_21/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491714: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_21/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491717: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_22/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491719: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_22/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491722: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_23/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491725: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_23/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491728: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_24/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491731: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_24/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491734: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_25/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491737: I tensorflow/core/common_runtime/placer.cc:125] clip_by_value_25/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491740: I tensorflow/core/common_runtime/placer.cc:125] beta1_power/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491742: I tensorflow/core/common_runtime/placer.cc:125] beta2_power/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491747: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d/kernel/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491750: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d/kernel/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491753: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491756: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491758: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_1/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491761: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_1/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491764: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491767: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_1/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491769: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_1/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491772: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_1/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491775: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_2/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491777: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_2/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491780: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_2/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491782: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_2/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491785: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_2/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491788: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_2/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491791: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_3/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491793: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_3/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491796: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_3/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491799: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_3/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491802: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_3/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491804: I tensorflow/core/common_runtime/placer.cc:125] encoder/conv2d_3/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491807: I tensorflow/core/common_runtime/placer.cc:125] encoder/dense/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491810: I tensorflow/core/common_runtime/placer.cc:125] encoder/dense/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491812: I tensorflow/core/common_runtime/placer.cc:125] encoder/dense/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491815: I tensorflow/core/common_runtime/placer.cc:125] encoder/dense/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491818: I tensorflow/core/common_runtime/placer.cc:125] encoder/dense/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491820: I tensorflow/core/common_runtime/placer.cc:125] encoder/dense/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491823: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_mean/kernel/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491826: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_mean/kernel/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491829: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_mean/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491832: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_mean/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491835: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_std_dev/kernel/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491837: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_std_dev/kernel/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491840: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_std_dev/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491843: I tensorflow/core/common_runtime/placer.cc:125] encoder/code_std_dev/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491847: I tensorflow/core/common_runtime/placer.cc:125] decoder/dense/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491850: I tensorflow/core/common_runtime/placer.cc:125] decoder/dense/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491852: I tensorflow/core/common_runtime/placer.cc:125] decoder/dense/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491855: I tensorflow/core/common_runtime/placer.cc:125] decoder/dense/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491858: I tensorflow/core/common_runtime/placer.cc:125] decoder/dense/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491861: I tensorflow/core/common_runtime/placer.cc:125] decoder/dense/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491863: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491866: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491868: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491871: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491874: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491876: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491879: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_1/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491882: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_1/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491887: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491890: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_1/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491892: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_1/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491895: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_1/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491898: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_2/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491900: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_2/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491903: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_2/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491906: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_2/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491908: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_2/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491911: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_2/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491914: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_3/kernel/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491917: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_3/kernel/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491919: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_3/kernel/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491922: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_3/kernel/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491924: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_3/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491927: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_3/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491929: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_4/kernel/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491932: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_4/kernel/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491934: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_4/bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491937: I tensorflow/core/common_runtime/placer.cc:125] decoder/conv2d_4/bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491942: I tensorflow/core/common_runtime/placer.cc:125] Adam/beta1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491946: I tensorflow/core/common_runtime/placer.cc:125] Adam/beta2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491949: I tensorflow/core/common_runtime/placer.cc:125] Adam/epsilon: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491952: I tensorflow/core/common_runtime/placer.cc:125] save/filename/input: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491955: I tensorflow/core/common_runtime/placer.cc:125] save/SaveV2/tensor_names: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491958: I tensorflow/core/common_runtime/placer.cc:125] save/SaveV2/shape_and_slices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491961: I tensorflow/core/common_runtime/placer.cc:125] save/RestoreV2/tensor_names: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-01-29 14:48:15.491964: I tensorflow/core/common_runtime/placer.cc:125] save/RestoreV2/shape_and_slices: (Const): /job:localhost/replica:0/task:0/device:CPU:0

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# Out:
# Finish processing the embeddings of the entire dataset.
# The first a few embeddings are
# [[ 0.00185114  0.01593742  0.00293605  0.01333947  0.00780422 -0.00133328]
#  [-0.00051402  0.01657126  0.00110879  0.00991673  0.00658684 -0.00264137]
#  [ 0.00230243  0.01458094  0.00655795  0.00722262  0.00652688  0.00100483]
#  [ 0.00800169  0.02130148  0.00173485 -0.01136279  0.01275335  0.00925046]
#  [ 0.0128335   0.05420278 -0.00493146  0.00911685  0.04992888 -0.00264075]]
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 11, 6)]           0
#
#  lstm (LSTM)                 (None, 11, 64)            18176
#
#  lstm_1 (LSTM)               (None, 11, 64)            33024
#
#  lstm_2 (LSTM)               (None, 11, 6)             1704
#
# =================================================================
# Total params: 52904 (206.66 KB)
# Trainable params: 52904 (206.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ../experiments/local-results/NAB/machine_temp/batch-32/NAB-machine_temp-48-12-6-fixedSigma-0.1/checkpoint/lstm/checkpoint
# No LSTM model loaded.

# %%
# load normalised time series
save_dir = '../datasets/NAB-known-anomaly/'
dataset = config['dataset']
filename = '{}.npz'.format(dataset)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    rolling_windows = np.zeros((n_vae_win, config['l_win']))
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win']))
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
test_windows = np.expand_dims(test_windows, -1)
test_seq = np.expand_dims(test_seq, -1)
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 5000 samples
# (4953, 48, 1)
# (4425, 12, 48, 1)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], 1)),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])
# Out:
# global_step/global_step: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/global_step/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/global_step/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# global_step/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/cur_epoch: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/cur_epoch/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/cur_epoch/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# cur_epoch/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Equal: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Equal_1: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/LogicalAnd: (LogicalAnd): /job:localhost/replica:0/task:0/device:CPU:0
# seed2: (SelectV2): /job:localhost/replica:0/task:0/device:CPU:0
# ShuffleDataset: (ShuffleDataset): /job:localhost/replica:0/task:0/device:CPU:0
# RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# BatchDatasetV2: (BatchDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# IteratorV2: (IteratorV2): /job:localhost/replica:0/task:0/device:CPU:0
# MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# IteratorToStringHandle: (IteratorToStringHandle): /job:localhost/replica:0/task:0/device:CPU:0
# IteratorGetNext: (IteratorGetNext): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/ExpandDims: (ExpandDims): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_1/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_2/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/conv2d_3/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/dense/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_mean/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/code_std_dev/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/concat/values_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/LinearOperatorDiag/shape_tensor/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/LinearOperatorDiag/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/shapes_from_loc_and_scale/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/MultivariateNormalDiag/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Prod_1: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/floordiv: (FloorDiv): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Maximum: (Maximum): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat/values_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/concat/values_0: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/concat/values_0: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/normal/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/normal/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/normal/random_normal: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Shape_2: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/strided_slice_2: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Normal/sample/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/transpose: (Transpose): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/sample/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/event_shape_tensor/event_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/SampleNormal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/BatchBroadcastSampleNormal/batch_shape_tensor_1/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/BroadcastArgs_1: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/Normal/batch_shape_tensor/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/BroadcastArgs: (BroadcastArgs): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SampleNormal/batch_shape_tensor_1/batch_shape: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/NotEqual: (NotEqual): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/SelectV2: (SelectV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_2: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/transpose: (Transpose): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_3: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/concat_4: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/BatchBroadcastSampleNormal/sample/Reshape_2: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/chain_of_shift_of_scale_matvec_linear_operator/forward/scale_matvec_linear_operator/forward/LinearOperatorDiag/matvec/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# encoder/MultivariateNormalDiag/sample/chain_of_shift_of_scale_matvec_linear_operator/forward/shift/forward/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Switch: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/switch_t: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/switch_f: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/pred_id: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Switch_1: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Switch_2: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/cond/Merge: (Merge): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/dense/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_1/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/DepthToSpace: (DepthToSpace): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_2: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_2/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/DepthToSpace_1: (DepthToSpace): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_3: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_3/LeakyRelu: (LeakyRelu): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/DepthToSpace_2: (DepthToSpace): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_4: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/conv2d_4/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# decoder/Reshape_5: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# sigma2_dataset/Square: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Square: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Square_1: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# loss/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Square_2: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Log: (Log): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Sum_2: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# loss/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# loss/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# loss/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Mean: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Mean_1: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# loss/sub_2: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Square_3: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Sum_3: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Mean_2: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# loss/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# loss/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# loss/sub_3: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Square_4: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Sum_4: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Mean_3: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# loss/Log_1: (Log): /job:localhost/replica:0/task:0/device:CPU:0
# loss/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# loss/mul_3: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# loss/add_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# loss/mul_4: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# loss/add_2: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# loss/add_3: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/add_3_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/add_3_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/add_3_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/add_2_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/add_2_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/add_2_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_4_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_4_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_4_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_4_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_4_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/mul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/truediv_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_1_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Mean_2_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/sub_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/range: (Range): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/ones: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/DynamicStitch: (DynamicStitch): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/loss/Sum_3_grad/BroadcastTo: (BroadcastTo): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# lstm_1/TensorArrayUnstack/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/TensorArrayUnstack/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/TensorArrayUnstack/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/TensorArrayUnstack/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/TensorArrayUnstack/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/split/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/split_1/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/clip_by_value/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/clip_by_value/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/clip_by_value_1/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/clip_by_value_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/Const_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/Const_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/clip_by_value_2/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/lstm_cell_1/clip_by_value_2/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/time: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/split/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/split_1/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/clip_by_value/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/clip_by_value/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/clip_by_value_1/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/clip_by_value_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/Const_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/Const_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/clip_by_value_2/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/lstm_cell/clip_by_value_2/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/while/add/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/TensorArrayStack/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/TensorArrayStack/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_1/transpose_1/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/kernel/Initializer/random_uniform/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/kernel/Initializer/random_uniform/min: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/kernel/Initializer/random_uniform/max: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/recurrent_kernel/Initializer/random_normal/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/recurrent_kernel/Initializer/random_normal/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/recurrent_kernel/Initializer/random_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/recurrent_kernel/Initializer/matrix_transpose/transpose/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/recurrent_kernel/Initializer/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/recurrent_kernel/Initializer/mul_1/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/bias/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/bias/Initializer/ones: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/bias/Initializer/zeros_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell/bias/Initializer/concat/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/zeros/packed/1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/zeros_1/packed/1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/zeros_1/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/transpose/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayUnstack/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayUnstack/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayUnstack/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayUnstack/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayUnstack/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/split/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/split_1/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/clip_by_value/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/clip_by_value/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/clip_by_value_1/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/clip_by_value_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/Const_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/Const_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/clip_by_value_2/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/lstm_cell_1/clip_by_value_2/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/time: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/split/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/split_1/split_dim: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/clip_by_value/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/clip_by_value/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/clip_by_value_1/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/clip_by_value_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/Const_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/Const_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/clip_by_value_2/Minimum/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/lstm_cell/clip_by_value_2/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/while/add/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayStack/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/TensorArrayStack/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2/transpose_1/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# lstm_2_target: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# total/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# count_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# metrics/mean_squared_error/Mean/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# metrics/mean_squared_error/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/lstm_2_loss/Mean/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/lstm_2_loss/weighted_loss/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/lstm_2_loss/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/lstm_2_loss/Rank: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/lstm_2_loss/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/lstm_2_loss/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# loss_1/mul/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 432855.7700077374
# 75% percentile: 5115678.610868693
# These windows scored the top 1% of anomaly metric (44492881.1346133):
# [ 456  457  458  459  460  461  690  691  692  770 1008]

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 185.64741635020846
# 75% percentile: 658.92118836562
# These windows scored the top 1% of anomaly metric (1518.977010027152):
# [ 31  54  55  80 112 371 751 844 899 913]

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 4425

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 982.3629606640434
# 75% percentile: 3667.1610795840666
# These windows scored the top 1% of anomaly metric (7174.284247921856):
# [3487 3547 3548 3549 3550 3551 3552 3553 3554 3555 3556 3557 3558 3559
#  3560 3561 3562 3563 3564 3565 3566 3567 3568 3569 3570 3571 3572 3573
#  3574 3575 3576 3577 3578 3579 3580 3581 3582 3583 3584 3585 3586 3587
#  3588 3589 3590]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (4425,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.6965046888320545
# Best threshold is 3114.923337442685
# At this threshold, precision is 0.6842546063651591, recall is 0.7092013888888888
# Average precision is 0.7205975578545586
#
# Augmented detection:
# Best F1 score is 0.9572081429164936
# Best threshold is 6391.858248033683
# At this threshold, precision is 0.9179282868525896, recall is 1.0
# Average precision is 0.9589641434262948

# %%
# Now select a threshold
threshold = 4399

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# Threshold is 4399
#
# PR evaluation using augmented detection:
# Precision: 0.8129851799576571
# Recall: 1.0
# F1: 0.8968470221876217
# TP: 1152
# FP: 265
# FN: 0

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
                                                                                        result['train_m'], 
                                                                                        result['train_std'],
                                                                                        detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
# Out:
# Detected 2 sequences
